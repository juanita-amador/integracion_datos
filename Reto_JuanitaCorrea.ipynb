# %% [markdown]
# # **Eficiencia logística basada en datos:** caso de empresa global de e-commerce

# %% [markdown]
# # **Descripción**

# %% [markdown]
# La empresa internacional de e-commerce especializada en productos electrónicos enfrenta el reto de reducir sus bloques de almacenamiento de seis (A–F) a tres (A–C) por restricciones presupuestales. Para lograrlo, busca apoyarse en un proceso de integración de datos multidimensional que le permita reorganizar su operación sin afectar la eficiencia ni la satisfacción del cliente.
#
# El dataset disponible, con 10.999 observaciones y 12 variables, ofrece información clave sobre clientes, productos, envíos y tiempos de entrega, lo que facilita identificar patrones y diseñar estrategias para optimizar la logística. Resolver esta situación es crucial, ya que una correcta redistribución reducirá costos, mejorará los tiempos de entrega y fortalecerá la competitividad de la compañía en el mercado global de e-commerce.
#
#
# ---
#
# ## **Sobre la base de datos**
#
#
# El [dataset](https://www.kaggle.com/datasets/prachi13/customer-analytics) cuenta con 12 variables que describen tanto características de los clientes como de los productos y la logística. Incluye un ID único por cliente, el bloque de almacén (A–E) y el modo de envío (Ship, Flight o Road). También registra el número de llamadas al servicio al cliente, la calificación del cliente (1–5), el costo del producto en dólares, las compras previas, el nivel de importancia del producto (Low, Medium, High), el género del cliente, el descuento aplicado, el peso en gramos y, finalmente, la variable objetivo Reached on time, que indica si el producto llegó a tiempo (0) o no (1).

# %% [markdown]
# # **Carga de librerías y datos**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis
import random as rnd #genera numeros entre 0 y 1
import warnings
warnings.filterwarnings('ignore')

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
nxl = '/content/drive/MyDrive/Semestre 8/Integración/retico/Train.csv'
XDB = pd.read_csv(nxl)

# %% [markdown]
# # **Caracterización**
# Debemos realizar una caracterización estadística de las variables dentro de cada bloque actual. Es decir, analizar cómo se comportan las variables cuantitativas y cualitativas en cada bloque, para luego tener una base sólida al momento de agruparlos o redistribuirlos.

# %% [markdown]
# ## General

# %%
XDB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10999 non-null  object
#  3   Customer_care_calls  10999 non-null  int64
#  4   Customer_rating      10999 non-null  int64
#  5   Cost_of_the_Product  10999 non-null  int64
#  6   Prior_purchases      10999 non-null  int64
#  7   Product_importance   10999 non-null  object
#  8   Gender               10999 non-null  object
#  9   Discount_offered     10999 non-null  int64
#  10  Weight_in_gms        10999 non-null  int64
#  11  Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 1.0+ MB

# %%
XDB.describe()
# Out:
#                 ID  Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# count  10999.00000         10999.000000     10999.000000         10999.000000
# mean    5500.00000             4.054459         2.990545           210.196836
# std     3175.28214             1.141490         1.413603            48.063272
# min        1.00000             2.000000         1.000000            96.000000
# 25%     2750.50000             3.000000         2.000000           169.000000
# 50%     5500.00000             4.000000         3.000000           214.000000
# 75%     8249.50000             5.000000         4.000000           251.000000
# max    10999.00000             7.000000         5.000000           310.000000
#
#        Prior_purchases  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# count     10999.000000      10999.000000   10999.000000         10999.000000
# mean          3.567597         13.373216    3634.016729             0.596691
# std           1.522860         16.205527    1635.377251             0.490584
# min           2.000000          1.000000    1001.000000             0.000000
# 25%           3.000000          4.000000    1839.500000             0.000000
# 50%           3.000000          7.000000    4149.000000             1.000000
# 75%           4.000000         10.000000    5050.000000             1.000000
# max          10.000000         65.000000    7846.000000             1.000000

# %%
XDB.columns
# Out:
# Index(['ID', 'Warehouse_block', 'Mode_of_Shipment', 'Customer_care_calls',
#        'Customer_rating', 'Cost_of_the_Product', 'Prior_purchases',
#        'Product_importance', 'Gender', 'Discount_offered', 'Weight_in_gms',
#        'Reached.on.Time_Y.N'],
#       dtype='object')

# %%
XDB["Warehouse_block"].unique()
# Out:
# array(['D', 'F', 'A', 'B', 'C'], dtype=object)

# %% [markdown]
# ## Categóricas

# %%
freq_table_Mode_of_Shipment = pd.crosstab(XDB["Warehouse_block"], XDB["Mode_of_Shipment"], normalize='index') * 100
freq_table_Product_importance = pd.crosstab(XDB["Warehouse_block"], XDB["Product_importance"], normalize='index') * 100
freq_table_Gender = pd.crosstab(XDB["Warehouse_block"], XDB["Gender"], normalize='index') * 100

print(freq_table_Mode_of_Shipment)
print(freq_table_Product_importance)
print(freq_table_Gender)
# Out:
# Mode_of_Shipment     Flight       Road       Ship
# Warehouse_block
# A                 16.202946  16.039280  67.757774
# B                 16.148391  16.039280  67.812330
# C                 16.093835  16.039280  67.866885
# D                 16.194111  15.921483  67.884406
# F                 16.148391  15.984724  67.866885
# Product_importance      high        low     medium
# Warehouse_block
# A                   9.001637  49.590835  41.407529
# B                   7.965085  46.644845  45.390071
# C                   9.165303  47.681397  43.153301
# D                   9.051254  48.146129  42.802617
# F                   8.265139  48.445172  43.289689
# Gender                   F          M
# Warehouse_block
# A                50.627387  49.372613
# B                49.536279  50.463721
# C                50.245499  49.754501
# D                50.872410  49.127590
# F                50.600109  49.399891

# %% [markdown]
# ## Numéricas

# %%
numeric_vars = ['Customer_care_calls', 'Customer_rating', 'Cost_of_the_Product', 'Prior_purchases', 'Discount_offered', 'Weight_in_gms']

# Función para caracterizar cada variable
def describe_numeric(data, var):
    serie = data[var]
    descripcion = {
        'Variable': var,
        'Media': np.mean(serie),
        'Desviación estándar': np.std(serie, ddof=1),
        'Asimetría': skew(serie),
        'Curtosis': kurtosis(serie)
    }
    return descripcion

# Aplicar a todas las variables numéricas
resultados = pd.DataFrame([describe_numeric(XDB, var) for var in numeric_vars])

print(resultados)
# Out:
#               Variable        Media  Desviación estándar  Asimetría  Curtosis
# 0  Customer_care_calls     4.054459             1.141490   0.391872 -0.309400
# 1      Customer_rating     2.990545             1.413603   0.004359 -1.295611
# 2  Cost_of_the_Product   210.196836            48.063272  -0.157096 -0.972264
# 3      Prior_purchases     3.567597             1.522860   1.681668  4.003976
# 4     Discount_offered    13.373216            16.205527   1.798684  1.999131
# 5        Weight_in_gms  3634.016729          1635.377251  -0.249713 -1.447558

# %% [markdown]
# # **Determinar y crear clústers**
#
# Dado que la empresa reducirá los bloques de A-F a A-C, necesitamos un proceso de integración de referencia. Para eso, vamos a agrupar (clusterizar) los datos de cada bloque actual y obtener un valor representativo (medoide) que sirva como referencia en la nueva distribución.
#
# En el proceso de clusterización mediante, la variable Warehouse_block no se utiliza directamente para agrupar, ya que precisamente buscamos reducir sus seis categorías a tres bloques representativos. Para formar los clusters se consideran únicamente las variables numéricas del dataset —como Cost_of_the_Product, Discount_offered, Weight_in_gms, Customer_care_calls, Prior_purchases y Customer_rating—, las cuales describen cuantitativamente a los productos y clientes. Estas variables permiten calcular similitudes entre observaciones y, a partir de ello, reorganizar los bloques en tres nuevos grupos de referencia más eficientes.

# %%
XD = XDB[numeric_vars].values
yd = XDB['Reached.on.Time_Y.N'].values  # variable objetivo

np.random.seed(42)

# Valores mínimos y máximos
Xmin = np.min(XD, axis=0)
Xmax = np.max(XD, axis=0)
print("Los valores mínimos son:", Xmin)
print("Los valores máximos son:", Xmax)

# Inicializar clusters (3 en este caso, porque queremos A, B, C)
k = 3
XC = np.zeros((k, XD.shape[1]))

for j in range(k):
    # Inicialización aleatoria
    XC[j, ] = Xmin + (Xmax - Xmin) * rnd.random()
    # Opción alternativa: tomar algunos individuos como medoides iniciales
    XC[j, ] = XD[j, ]

# Asignación de clusters
fhat = np.zeros((len(XD), 1))

for idx in range(len(XD)):
    # Distancia euclídea inversa (similitud)
    VP = np.exp(-0.5 * (np.mean(((XC[:, ] - XD[idx, ]) / XC[:, ]) ** 2, axis=1)))
    nc = np.argmax(VP)   # cluster más cercano
    fhat[idx, ] = int(nc)
    # Actualización del medoide
    XC[nc, ] = (XC[nc, ] + XD[idx, ]) / 2

# Resumen por cluster
fhat2 = np.zeros((k, 2))
for j in range(k):
    filas = np.where(fhat[:, ] == j)[0]
    npx = len(filas)
    print("El número de observaciones en el bloque", j, "es", npx)

    # Conteo de Reached.on.Time_Y.N
    if npx > 0:
        fhat2[j, 1] = len(np.where(yd[filas] == 1)[0])  # No llegó a tiempo
        fhat2[j, 0] = len(np.where(yd[filas] == 0)[0])  # Sí llegó a tiempo
        fhat2[j, ] = fhat2[j, ] / np.sum(fhat2[j, ])    # Proporción

# Concatenar y resumen
XCT = np.column_stack((XC, fhat2))

dfXC = pd.DataFrame(XCT)
dfXC.columns = numeric_vars + ['OnTime_Prop', 'Late_Prop']
dfXC.index = ['Cluster A', 'Cluster B', 'Cluster C']

display(dfXC)
# Out:
# Los valores mínimos son: [   2    1   96    2    1 1001]
# Los valores máximos son: [   7    5  310   10   65 7846]
# El número de observaciones en el bloque 0 es 3494
# El número de observaciones en el bloque 1 es 4423
# El número de observaciones en el bloque 2 es 3082
#            Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# Cluster A             4.449562         1.001030           253.270129
# Cluster B             3.432319         3.719437           192.985053
# Cluster C             4.617830         1.051206           243.202633
#
#            Prior_purchases  Discount_offered  Weight_in_gms  OnTime_Prop  \
# Cluster A         5.269662          1.012622    1381.870639     0.477676
# Cluster B         5.262020          4.812524    1425.684728     0.239882
# Cluster C         5.050843          2.675291    1670.335695     0.553537
#
#            Late_Prop
# Cluster A   0.522324
# Cluster B   0.760118
# Cluster C   0.446463

# %% [markdown]
# # **Integración de Datos**
# El siguiente paso es la integración. La integración consiste en reasignar los datos de los bloques originales C, D, E y F hacia los nuevos bloques de referencia A, B y C obtenidos con K-Medoids. Para ello, se calcula el grado de pertenencia de cada observación a los tres clusters a partir de la distancia a sus medoides, y cada dato se integra en el bloque con el que tenga la mayor similitud, consolidando así la estructura de solo tres bloques.

# %%
# Datos de referencia (medoides iniciales: clusters A, B, C)
XC2 = np.copy(XC)

# Subconjunto de datos a integrar: bloques C, D, E, F
XD2 = XDB[XDB['Warehouse_block'].isin(['C', 'D', 'E', 'F'])][numeric_vars].values

# Proceso de integración
for k in range(len(XD2)):
    # Grado de pertenencia a cada cluster
    VP2 = np.exp(-0.5 * (np.mean(((XC - XD2[k, ]) / XC) ** 2, axis=1)))
    VP2Ing = np.exp(-0.5 * (((XC[:, 2] - XD2[k, 2]) / XC[:, 2]) ** 2))  # aquí se usa la variable "Cost_of_the_Product"

    # Condición de integración: si la pertenencia a algún cluster es suficientemente alta
    if np.max(VP2Ing) > 0.95:
        nc2 = np.argmax(VP2)  # cluster más cercano
        print("El producto", k, "pertenece al bloque", nc2)

        # Actualizamos el medoide correspondiente
        XC2[nc2, ] = (XC2[nc2, ] + XD2[k, ]) / 2

# Mostrar clusters originales (medoides iniciales)
dfXC = pd.DataFrame(XC, columns=numeric_vars, index=['Cluster A', 'Cluster B', 'Cluster C'])
print("Medoides originales (clusters de referencia):")
display(dfXC)

# Mostrar clusters modificados tras la integración
dfXC2 = pd.DataFrame(XC2, columns=numeric_vars, index=['Cluster A', 'Cluster B', 'Cluster C'])
print("Medoides tras la integración:")
display(dfXC2)

# Cambios porcentuales en las variables de cada cluster
print("Cambios porcentuales en cada variable por cluster:\n")
cambios = pd.DataFrame(np.abs((XC - XC2) / XC), columns=numeric_vars, index=['Cluster A', 'Cluster B', 'Cluster C'])
display(cambios)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# El producto 2201 pertenece al bloque 1
# El producto 2202 pertenece al bloque 1
# El producto 2203 pertenece al bloque 1
# El producto 2204 pertenece al bloque 1
# El producto 2205 pertenece al bloque 1
# El producto 2206 pertenece al bloque 1
# El producto 2207 pertenece al bloque 2
# El producto 2208 pertenece al bloque 1
# El producto 2209 pertenece al bloque 1
# El producto 2210 pertenece al bloque 1
# El producto 2211 pertenece al bloque 1
# El producto 2212 pertenece al bloque 2
# El producto 2213 pertenece al bloque 1
# El producto 2214 pertenece al bloque 1
# El producto 2215 pertenece al bloque 2
# El producto 2216 pertenece al bloque 1
# El producto 2217 pertenece al bloque 1
# El producto 2218 pertenece al bloque 1
# El producto 2219 pertenece al bloque 1
# El producto 2220 pertenece al bloque 1
# El producto 2221 pertenece al bloque 1
# El producto 2222 pertenece al bloque 1
# El producto 2223 pertenece al bloque 1
# El producto 2224 pertenece al bloque 1
# El producto 2225 pertenece al bloque 2
# El producto 2226 pertenece al bloque 1
# El producto 2227 pertenece al bloque 1
# El producto 2228 pertenece al bloque 1
# El producto 2229 pertenece al bloque 2
# El producto 2230 pertenece al bloque 1
# El producto 2231 pertenece al bloque 2
# El producto 2232 pertenece al bloque 2
# El producto 2233 pertenece al bloque 1
# El producto 2234 pertenece al bloque 1
# El producto 2235 pertenece al bloque 1
# El producto 2236 pertenece al bloque 1
# El producto 2237 pertenece al bloque 1
# El producto 2238 pertenece al bloque 1
# El producto 2239 pertenece al bloque 1
# El producto 2240 pertenece al bloque 1
# El producto 2241 pertenece al bloque 2
# El producto 2242 pertenece al bloque 2
# El producto 2243 pertenece al bloque 1
# El producto 2244 pertenece al bloque 1
# El producto 2245 pertenece al bloque 2
# El producto 2246 pertenece al bloque 1
# El producto 2247 pertenece al bloque 1
# El producto 2248 pertenece al bloque 1
# El producto 2249 pertenece al bloque 1
# El producto 2250 pertenece al bloque 2
# El producto 2251 pertenece al bloque 1
# El producto 2252 pertenece al bloque 1
# El producto 2253 pertenece al bloque 1
# El producto 2254 pertenece al bloque 1
# El producto 2255 pertenece al bloque 1
# El producto 2256 pertenece al bloque 1
# El producto 2257 pertenece al bloque 1
# El producto 2258 pertenece al bloque 2
# El producto 2259 pertenece al bloque 1
# El producto 2260 pertenece al bloque 1
# El producto 2261 pertenece al bloque 1
# El producto 2262 pertenece al bloque 1
# El producto 2263 pertenece al bloque 1
# El producto 2264 pertenece al bloque 1
# El producto 2265 pertenece al bloque 1
# El producto 2266 pertenece al bloque 2
# El producto 2267 pertenece al bloque 1
# El producto 2268 pertenece al bloque 2
# El producto 2270 pertenece al bloque 2
# El producto 2271 pertenece al bloque 1
# El producto 2272 pertenece al bloque 2
# El producto 2273 pertenece al bloque 1
# El producto 2274 pertenece al bloque 1
# El producto 2275 pertenece al bloque 2
# El producto 2276 pertenece al bloque 2
# El producto 2277 pertenece al bloque 1
# El producto 2278 pertenece al bloque 1
# El producto 2279 pertenece al bloque 1
# El producto 2280 pertenece al bloque 2
# El producto 2281 pertenece al bloque 1
# El producto 2282 pertenece al bloque 1
# El producto 2283 pertenece al bloque 1
# El producto 2284 pertenece al bloque 1
# El producto 2285 pertenece al bloque 1
# El producto 2286 pertenece al bloque 1
# El producto 2287 pertenece al bloque 1
# El producto 2288 pertenece al bloque 2
# El producto 2289 pertenece al bloque 1
# El producto 2290 pertenece al bloque 1
# El producto 2291 pertenece al bloque 1
# El producto 2292 pertenece al bloque 2
# El producto 2293 pertenece al bloque 1
# El producto 2294 pertenece al bloque 1
# El producto 2295 pertenece al bloque 2
# El producto 2296 pertenece al bloque 1
# El producto 2297 pertenece al bloque 2
# El producto 2298 pertenece al bloque 1
# El producto 2299 pertenece al bloque 2
# El producto 2300 pertenece al bloque 1
# El producto 2301 pertenece al bloque 1
# El producto 2302 pertenece al bloque 1
# El producto 2303 pertenece al bloque 1
# El producto 2304 pertenece al bloque 1
# El producto 2305 pertenece al bloque 1
# El producto 2306 pertenece al bloque 1
# El producto 2307 pertenece al bloque 1
# El producto 2308 pertenece al bloque 1
# El producto 2309 pertenece al bloque 1
# El producto 2310 pertenece al bloque 1
# El producto 2311 pertenece al bloque 1
# El producto 2312 pertenece al bloque 1
# El producto 2313 pertenece al bloque 1
# El producto 2314 pertenece al bloque 1
# El producto 2315 pertenece al bloque 2
# El producto 2316 pertenece al bloque 2
# El producto 2318 pertenece al bloque 2
# El producto 2319 pertenece al bloque 2
# El producto 2320 pertenece al bloque 1
# El producto 2321 pertenece al bloque 1
# El producto 2322 pertenece al bloque 1
# El producto 2323 pertenece al bloque 1
# El producto 2324 pertenece al bloque 1
# El producto 2325 pertenece al bloque 1
# El producto 2326 pertenece al bloque 2
# El producto 2327 pertenece al bloque 2
# El producto 2328 pertenece al bloque 2
# El producto 2329 pertenece al bloque 1
# El producto 2330 pertenece al bloque 1
# El producto 2331 pertenece al bloque 1
# El producto 2332 pertenece al bloque 2
# El producto 2333 pertenece al bloque 1
# El producto 2334 pertenece al bloque 2
# El producto 2335 pertenece al bloque 2
# El producto 2336 pertenece al bloque 1
# El producto 2337 pertenece al bloque 1
# El producto 2338 pertenece al bloque 1
# El producto 2339 pertenece al bloque 1
# El producto 2341 pertenece al bloque 1
# El producto 2342 pertenece al bloque 1
# El producto 2343 pertenece al bloque 1
# El producto 2344 pertenece al bloque 1
# El producto 2345 pertenece al bloque 1
# El producto 2346 pertenece al bloque 1
# El producto 2347 pertenece al bloque 1
# El producto 2348 pertenece al bloque 1
# El producto 2349 pertenece al bloque 1
# El producto 2350 pertenece al bloque 2
# El producto 2351 pertenece al bloque 1
# El producto 2352 pertenece al bloque 1
# El producto 2353 pertenece al bloque 1
# El producto 2354 pertenece al bloque 1
# El producto 2355 pertenece al bloque 2
# El producto 2356 pertenece al bloque 1
# El producto 2357 pertenece al bloque 1
# El producto 2358 pertenece al bloque 1
# El producto 2359 pertenece al bloque 1
# El producto 2360 pertenece al bloque 1
# El producto 2361 pertenece al bloque 2
# El producto 2362 pertenece al bloque 1
# El producto 2363 pertenece al bloque 1
# El producto 2364 pertenece al bloque 2
# El producto 2365 pertenece al bloque 1
# El producto 2366 pertenece al bloque 2
# El producto 2367 pertenece al bloque 2
# El producto 2368 pertenece al bloque 2
# El producto 2369 pertenece al bloque 1
# El producto 2370 pertenece al bloque 1
# El producto 2371 pertenece al bloque 1
# El producto 2372 pertenece al bloque 1
# El producto 2373 pertenece al bloque 1
# El producto 2374 pertenece al bloque 2
# El producto 2375 pertenece al bloque 1
# El producto 2376 pertenece al bloque 1
# El producto 2377 pertenece al bloque 2
# El producto 2378 pertenece al bloque 1
# El producto 2380 pertenece al bloque 1
# El producto 2381 pertenece al bloque 1
# El producto 2382 pertenece al bloque 1
# El producto 2383 pertenece al bloque 1
# El producto 2384 pertenece al bloque 1
# El producto 2386 pertenece al bloque 1
# El producto 2387 pertenece al bloque 1
# El producto 2388 pertenece al bloque 1
# El producto 2389 pertenece al bloque 1
# El producto 2390 pertenece al bloque 2
# El producto 2391 pertenece al bloque 1
# El producto 2392 pertenece al bloque 1
# El producto 2394 pertenece al bloque 1
# El producto 2395 pertenece al bloque 2
# El producto 2396 pertenece al bloque 2
# El producto 2397 pertenece al bloque 2
# El producto 2398 pertenece al bloque 1
# El producto 2399 pertenece al bloque 1
# El producto 2400 pertenece al bloque 1
# El producto 2401 pertenece al bloque 1
# El producto 2402 pertenece al bloque 1
# El producto 2403 pertenece al bloque 2
# El producto 2404 pertenece al bloque 1
# El producto 2405 pertenece al bloque 1
# El producto 2406 pertenece al bloque 1
# El producto 2408 pertenece al bloque 2
# El producto 2409 pertenece al bloque 1
# El producto 2410 pertenece al bloque 1
# El producto 2411 pertenece al bloque 1
# El producto 2412 pertenece al bloque 1
# El producto 2413 pertenece al bloque 1
# El producto 2414 pertenece al bloque 2
# El producto 2415 pertenece al bloque 1
# El producto 2416 pertenece al bloque 1
# El producto 2417 pertenece al bloque 1
# El producto 2418 pertenece al bloque 2
# El producto 2419 pertenece al bloque 1
# El producto 2420 pertenece al bloque 1
# El producto 2421 pertenece al bloque 1
# El producto 2422 pertenece al bloque 1
# El producto 2423 pertenece al bloque 1
# El producto 2424 pertenece al bloque 1
# El producto 2425 pertenece al bloque 1
# El producto 2426 pertenece al bloque 2
# El producto 2427 pertenece al bloque 2
# El producto 2428 pertenece al bloque 1
# El producto 2429 pertenece al bloque 1
# El producto 2430 pertenece al bloque 1
# El producto 2431 pertenece al bloque 2
# El producto 2432 pertenece al bloque 2
# El producto 2433 pertenece al bloque 1
# El producto 2434 pertenece al bloque 1
# El producto 2435 pertenece al bloque 1
# El producto 2436 pertenece al bloque 1
# El producto 2437 pertenece al bloque 2
# El producto 2438 pertenece al bloque 1
# El producto 2439 pertenece al bloque 2
# El producto 2440 pertenece al bloque 1
# El producto 2441 pertenece al bloque 2
# El producto 2442 pertenece al bloque 1
# El producto 2443 pertenece al bloque 1
# El producto 2444 pertenece al bloque 1
# El producto 2445 pertenece al bloque 1
# El producto 2446 pertenece al bloque 2
# El producto 2447 pertenece al bloque 1
# El producto 2448 pertenece al bloque 2
# El producto 2449 pertenece al bloque 1
# El producto 2450 pertenece al bloque 2
# El producto 2451 pertenece al bloque 2
# El producto 2452 pertenece al bloque 1
# El producto 2453 pertenece al bloque 1
# El producto 2454 pertenece al bloque 1
# El producto 2455 pertenece al bloque 1
# El producto 2456 pertenece al bloque 1
# El producto 2457 pertenece al bloque 2
# El producto 2458 pertenece al bloque 1
# El producto 2459 pertenece al bloque 1
# El producto 2460 pertenece al bloque 1
# El producto 2461 pertenece al bloque 1
# El producto 2462 pertenece al bloque 2
# El producto 2464 pertenece al bloque 1
# El producto 2465 pertenece al bloque 2
# El producto 2466 pertenece al bloque 1
# El producto 2467 pertenece al bloque 1
# El producto 2468 pertenece al bloque 1
# El producto 2469 pertenece al bloque 1
# El producto 2470 pertenece al bloque 2
# El producto 2471 pertenece al bloque 1
# El producto 2472 pertenece al bloque 2
# El producto 2473 pertenece al bloque 2
# El producto 2475 pertenece al bloque 2
# El producto 2476 pertenece al bloque 1
# El producto 2477 pertenece al bloque 1
# El producto 2478 pertenece al bloque 1
# El producto 2479 pertenece al bloque 2
# El producto 2480 pertenece al bloque 1
# El producto 2481 pertenece al bloque 2
# El producto 2482 pertenece al bloque 1
# El producto 2483 pertenece al bloque 2
# El producto 2484 pertenece al bloque 1
# El producto 2485 pertenece al bloque 1
# El producto 2487 pertenece al bloque 1
# El producto 2488 pertenece al bloque 1
# El producto 2489 pertenece al bloque 1
# El producto 2490 pertenece al bloque 1
# El producto 2491 pertenece al bloque 1
# El producto 2492 pertenece al bloque 1
# El producto 2493 pertenece al bloque 1
# El producto 2494 pertenece al bloque 1
# El producto 2495 pertenece al bloque 2
# El producto 2496 pertenece al bloque 1
# El producto 2497 pertenece al bloque 2
# El producto 2498 pertenece al bloque 1
# El producto 2499 pertenece al bloque 1
# El producto 2500 pertenece al bloque 1
# El producto 2501 pertenece al bloque 1
# El producto 2503 pertenece al bloque 1
# El producto 2505 pertenece al bloque 1
# El producto 2506 pertenece al bloque 1
# El producto 2507 pertenece al bloque 2
# El producto 2508 pertenece al bloque 1
# El producto 2509 pertenece al bloque 1
# El producto 2510 pertenece al bloque 1
# El producto 2511 pertenece al bloque 1
# El producto 2512 pertenece al bloque 1
# El producto 2513 pertenece al bloque 1
# El producto 2514 pertenece al bloque 1
# El producto 2515 pertenece al bloque 1
# El producto 2516 pertenece al bloque 2
# El producto 2517 pertenece al bloque 1
# El producto 2518 pertenece al bloque 2
# El producto 2520 pertenece al bloque 1
# El producto 2521 pertenece al bloque 2
# El producto 2522 pertenece al bloque 1
# El producto 2523 pertenece al bloque 1
# El producto 2524 pertenece al bloque 2
# El producto 2525 pertenece al bloque 1
# El producto 2526 pertenece al bloque 1
# El producto 2527 pertenece al bloque 1
# El producto 2528 pertenece al bloque 2
# El producto 2529 pertenece al bloque 1
# El producto 2530 pertenece al bloque 1
# El producto 2531 pertenece al bloque 1
# El producto 2532 pertenece al bloque 1
# El producto 2533 pertenece al bloque 1
# El producto 2534 pertenece al bloque 2
# El producto 2535 pertenece al bloque 1
# El producto 2536 pertenece al bloque 1
# El producto 2537 pertenece al bloque 2
# El producto 2538 pertenece al bloque 2
# El producto 2539 pertenece al bloque 1
# El producto 2540 pertenece al bloque 2
# El producto 2541 pertenece al bloque 1
# El producto 2542 pertenece al bloque 1
# El producto 2543 pertenece al bloque 2
# El producto 2544 pertenece al bloque 1
# El producto 2545 pertenece al bloque 1
# El producto 2546 pertenece al bloque 1
# El producto 2547 pertenece al bloque 1
# El producto 2548 pertenece al bloque 1
# El producto 2549 pertenece al bloque 1
# El producto 2550 pertenece al bloque 1
# El producto 2551 pertenece al bloque 1
# El producto 2552 pertenece al bloque 1
# El producto 2553 pertenece al bloque 1
# El producto 2554 pertenece al bloque 2
# El producto 2555 pertenece al bloque 1
# El producto 2556 pertenece al bloque 2
# El producto 2557 pertenece al bloque 1
# El producto 2558 pertenece al bloque 2
# El producto 2559 pertenece al bloque 2
# El producto 2560 pertenece al bloque 2
# El producto 2561 pertenece al bloque 2
# El producto 2562 pertenece al bloque 1
# El producto 2563 pertenece al bloque 1
# El producto 2564 pertenece al bloque 1
# El producto 2565 pertenece al bloque 1
# El producto 2566 pertenece al bloque 1
# El producto 2567 pertenece al bloque 1
# El producto 2568 pertenece al bloque 1
# El producto 2569 pertenece al bloque 1
# El producto 2570 pertenece al bloque 1
# El producto 2571 pertenece al bloque 2
# El producto 2572 pertenece al bloque 1
# El producto 2573 pertenece al bloque 2
# El producto 2574 pertenece al bloque 2
# El producto 2575 pertenece al bloque 1
# El producto 2576 pertenece al bloque 2
# El producto 2577 pertenece al bloque 1
# El producto 2578 pertenece al bloque 1
# El producto 2579 pertenece al bloque 1
# El producto 2580 pertenece al bloque 1
# El producto 2581 pertenece al bloque 2
# El producto 2582 pertenece al bloque 1
# El producto 2583 pertenece al bloque 1
# El producto 2584 pertenece al bloque 1
# El producto 2585 pertenece al bloque 1
# El producto 2586 pertenece al bloque 2
# El producto 2587 pertenece al bloque 2
# El producto 2588 pertenece al bloque 1
# El producto 2589 pertenece al bloque 1
# El producto 2590 pertenece al bloque 1
# El producto 2591 pertenece al bloque 1
# El producto 2592 pertenece al bloque 1
# El producto 2593 pertenece al bloque 1
# El producto 2594 pertenece al bloque 2
# El producto 2595 pertenece al bloque 1
# El producto 2596 pertenece al bloque 1
# El producto 2597 pertenece al bloque 1
# El producto 2598 pertenece al bloque 1
# El producto 2599 pertenece al bloque 1
# El producto 2600 pertenece al bloque 1
# El producto 2601 pertenece al bloque 1
# El producto 2602 pertenece al bloque 2
# El producto 2603 pertenece al bloque 1
# El producto 2604 pertenece al bloque 1
# El producto 2605 pertenece al bloque 2
# El producto 2606 pertenece al bloque 1
# El producto 2609 pertenece al bloque 1
# El producto 2610 pertenece al bloque 1
# El producto 2611 pertenece al bloque 2
# El producto 2612 pertenece al bloque 2
# El producto 2613 pertenece al bloque 2
# El producto 2615 pertenece al bloque 2
# El producto 2616 pertenece al bloque 2
# El producto 2617 pertenece al bloque 2
# El producto 2618 pertenece al bloque 1
# El producto 2619 pertenece al bloque 1
# El producto 2621 pertenece al bloque 1
# El producto 2622 pertenece al bloque 1
# El producto 2623 pertenece al bloque 2
# El producto 2624 pertenece al bloque 1
# El producto 2625 pertenece al bloque 1
# El producto 2626 pertenece al bloque 1
# El producto 2627 pertenece al bloque 1
# El producto 2628 pertenece al bloque 2
# El producto 2629 pertenece al bloque 1
# El producto 2630 pertenece al bloque 1
# El producto 2631 pertenece al bloque 1
# El producto 2632 pertenece al bloque 2
# El producto 2633 pertenece al bloque 1
# El producto 2634 pertenece al bloque 1
# El producto 2635 pertenece al bloque 1
# El producto 2636 pertenece al bloque 2
# El producto 2637 pertenece al bloque 2
# El producto 2638 pertenece al bloque 2
# El producto 2639 pertenece al bloque 2
# El producto 2640 pertenece al bloque 2
# El producto 2641 pertenece al bloque 2
# El producto 2642 pertenece al bloque 2
# El producto 2643 pertenece al bloque 2
# El producto 2644 pertenece al bloque 1
# El producto 2645 pertenece al bloque 2
# El producto 2646 pertenece al bloque 1
# El producto 2647 pertenece al bloque 1
# El producto 2648 pertenece al bloque 2
# El producto 2649 pertenece al bloque 2
# El producto 2650 pertenece al bloque 2
# El producto 2651 pertenece al bloque 1
# El producto 2652 pertenece al bloque 2
# El producto 2653 pertenece al bloque 1
# El producto 2654 pertenece al bloque 2
# El producto 2655 pertenece al bloque 1
# El producto 2656 pertenece al bloque 2
# El producto 2658 pertenece al bloque 2
# El producto 2659 pertenece al bloque 1
# El producto 2660 pertenece al bloque 1
# El producto 2661 pertenece al bloque 1
# El producto 2662 pertenece al bloque 1
# El producto 2663 pertenece al bloque 1
# El producto 2664 pertenece al bloque 1
# El producto 2665 pertenece al bloque 1
# El producto 2666 pertenece al bloque 1
# El producto 2667 pertenece al bloque 1
# El producto 2668 pertenece al bloque 2
# El producto 2669 pertenece al bloque 2
# El producto 2670 pertenece al bloque 1
# El producto 2671 pertenece al bloque 2
# El producto 2673 pertenece al bloque 1
# El producto 2674 pertenece al bloque 2
# El producto 2675 pertenece al bloque 1
# El producto 2676 pertenece al bloque 1
# El producto 2678 pertenece al bloque 1
# El producto 2679 pertenece al bloque 1
# El producto 2680 pertenece al bloque 1
# El producto 2681 pertenece al bloque 1
# El producto 2682 pertenece al bloque 1
# El producto 2683 pertenece al bloque 1
# El producto 2684 pertenece al bloque 1
# El producto 2685 pertenece al bloque 1
# El producto 2686 pertenece al bloque 2
# El producto 2688 pertenece al bloque 1
# El producto 2689 pertenece al bloque 1
# El producto 2690 pertenece al bloque 1
# El producto 2691 pertenece al bloque 1
# El producto 2692 pertenece al bloque 1
# El producto 2694 pertenece al bloque 1
# El producto 2695 pertenece al bloque 1
# El producto 2696 pertenece al bloque 2
# El producto 2697 pertenece al bloque 2
# El producto 2698 pertenece al bloque 2
# El producto 2699 pertenece al bloque 1
# El producto 2700 pertenece al bloque 1
# El producto 2701 pertenece al bloque 1
# El producto 2702 pertenece al bloque 1
# El producto 2703 pertenece al bloque 1
# El producto 2704 pertenece al bloque 2
# El producto 2705 pertenece al bloque 2
# El producto 2706 pertenece al bloque 1
# El producto 2707 pertenece al bloque 1
# El producto 2709 pertenece al bloque 1
# El producto 2710 pertenece al bloque 1
# El producto 2711 pertenece al bloque 1
# El producto 2712 pertenece al bloque 1
# El producto 2713 pertenece al bloque 2
# El producto 2714 pertenece al bloque 1
# El producto 2715 pertenece al bloque 2
# El producto 2716 pertenece al bloque 1
# El producto 2717 pertenece al bloque 1
# El producto 2718 pertenece al bloque 1
# El producto 2719 pertenece al bloque 1
# El producto 2720 pertenece al bloque 1
# El producto 2721 pertenece al bloque 2
# El producto 2722 pertenece al bloque 1
# El producto 2723 pertenece al bloque 1
# El producto 2724 pertenece al bloque 1
# El producto 2725 pertenece al bloque 1
# El producto 2726 pertenece al bloque 1
# El producto 2727 pertenece al bloque 1
# El producto 2729 pertenece al bloque 2
# El producto 2730 pertenece al bloque 1
# El producto 2731 pertenece al bloque 2
# El producto 2732 pertenece al bloque 2
# El producto 2733 pertenece al bloque 2
# El producto 2734 pertenece al bloque 1
# El producto 2735 pertenece al bloque 1
# El producto 2736 pertenece al bloque 1
# El producto 2737 pertenece al bloque 2
# El producto 2738 pertenece al bloque 1
# El producto 2739 pertenece al bloque 2
# El producto 2740 pertenece al bloque 2
# El producto 2742 pertenece al bloque 2
# El producto 2743 pertenece al bloque 1
# El producto 2744 pertenece al bloque 1
# El producto 2745 pertenece al bloque 1
# El producto 2746 pertenece al bloque 2
# El producto 2747 pertenece al bloque 1
# El producto 2748 pertenece al bloque 2
# El producto 2749 pertenece al bloque 1
# El producto 2750 pertenece al bloque 1
# El producto 2751 pertenece al bloque 2
# El producto 2752 pertenece al bloque 2
# El producto 2753 pertenece al bloque 1
# El producto 2754 pertenece al bloque 1
# El producto 2756 pertenece al bloque 2
# El producto 2757 pertenece al bloque 2
# El producto 2758 pertenece al bloque 1
# El producto 2759 pertenece al bloque 1
# El producto 2760 pertenece al bloque 1
# El producto 2761 pertenece al bloque 1
# El producto 2762 pertenece al bloque 1
# El producto 2764 pertenece al bloque 1
# El producto 2765 pertenece al bloque 2
# El producto 2766 pertenece al bloque 1
# El producto 2767 pertenece al bloque 1
# El producto 2768 pertenece al bloque 1
# El producto 2769 pertenece al bloque 1
# El producto 2770 pertenece al bloque 2
# El producto 2771 pertenece al bloque 1
# El producto 2773 pertenece al bloque 1
# El producto 2774 pertenece al bloque 1
# El producto 2775 pertenece al bloque 1
# El producto 2776 pertenece al bloque 1
# El producto 2777 pertenece al bloque 1
# El producto 2778 pertenece al bloque 1
# El producto 2779 pertenece al bloque 1
# El producto 2780 pertenece al bloque 1
# El producto 2781 pertenece al bloque 2
# El producto 2782 pertenece al bloque 2
# El producto 2783 pertenece al bloque 1
# El producto 2784 pertenece al bloque 1
# El producto 2785 pertenece al bloque 1
# El producto 2786 pertenece al bloque 1
# El producto 2787 pertenece al bloque 1
# El producto 2788 pertenece al bloque 1
# El producto 2789 pertenece al bloque 2
# El producto 2790 pertenece al bloque 1
# El producto 2791 pertenece al bloque 1
# El producto 2792 pertenece al bloque 1
# El producto 2793 pertenece al bloque 2
# El producto 2795 pertenece al bloque 2
# El producto 2796 pertenece al bloque 1
# El producto 2797 pertenece al bloque 2
# El producto 2798 pertenece al bloque 1
# El producto 2799 pertenece al bloque 1
# El producto 2800 pertenece al bloque 2
# El producto 2801 pertenece al bloque 1
# El producto 2802 pertenece al bloque 1
# El producto 2803 pertenece al bloque 2
# El producto 2804 pertenece al bloque 1
# El producto 2805 pertenece al bloque 1
# El producto 2806 pertenece al bloque 1
# El producto 2807 pertenece al bloque 1
# El producto 2808 pertenece al bloque 1
# El producto 2809 pertenece al bloque 1
# El producto 2810 pertenece al bloque 1
# El producto 2811 pertenece al bloque 2
# El producto 2812 pertenece al bloque 1
# El producto 2813 pertenece al bloque 1
# El producto 2814 pertenece al bloque 1
# El producto 2815 pertenece al bloque 1
# El producto 2816 pertenece al bloque 1
# El producto 2817 pertenece al bloque 1
# El producto 2818 pertenece al bloque 1
# El producto 2819 pertenece al bloque 1
# El producto 2820 pertenece al bloque 2
# El producto 2821 pertenece al bloque 1
# El producto 2822 pertenece al bloque 1
# El producto 2823 pertenece al bloque 1
# El producto 2824 pertenece al bloque 1
# El producto 2825 pertenece al bloque 2
# El producto 2826 pertenece al bloque 2
# El producto 2827 pertenece al bloque 2
# El producto 2828 pertenece al bloque 1
# El producto 2829 pertenece al bloque 2
# El producto 2830 pertenece al bloque 1
# El producto 2831 pertenece al bloque 1
# El producto 2832 pertenece al bloque 1
# El producto 2833 pertenece al bloque 1
# El producto 2834 pertenece al bloque 1
# El producto 2835 pertenece al bloque 1
# El producto 2836 pertenece al bloque 1
# El producto 2837 pertenece al bloque 1
# El producto 2838 pertenece al bloque 1
# El producto 2839 pertenece al bloque 1
# El producto 2840 pertenece al bloque 2
# El producto 2841 pertenece al bloque 1
# El producto 2842 pertenece al bloque 1
# El producto 2843 pertenece al bloque 1
# El producto 2844 pertenece al bloque 2
# El producto 2845 pertenece al bloque 1
# El producto 2847 pertenece al bloque 2
# El producto 2848 pertenece al bloque 2
# El producto 2849 pertenece al bloque 1
# El producto 2850 pertenece al bloque 1
# El producto 2851 pertenece al bloque 2
# El producto 2852 pertenece al bloque 2
# El producto 2853 pertenece al bloque 1
# El producto 2854 pertenece al bloque 2
# El producto 2855 pertenece al bloque 1
# El producto 2856 pertenece al bloque 1
# El producto 2857 pertenece al bloque 1
# El producto 2858 pertenece al bloque 1
# El producto 2859 pertenece al bloque 1
# El producto 2860 pertenece al bloque 1
# El producto 2861 pertenece al bloque 2
# El producto 2862 pertenece al bloque 1
# El producto 2863 pertenece al bloque 1
# El producto 2864 pertenece al bloque 1
# El producto 2865 pertenece al bloque 1
# El producto 2866 pertenece al bloque 1
# El producto 2867 pertenece al bloque 2
# El producto 2868 pertenece al bloque 2
# El producto 2869 pertenece al bloque 1
# El producto 2870 pertenece al bloque 1
# El producto 2871 pertenece al bloque 1
# El producto 2872 pertenece al bloque 1
# El producto 2873 pertenece al bloque 1
# El producto 2874 pertenece al bloque 1
# El producto 2875 pertenece al bloque 1
# El producto 2876 pertenece al bloque 2
# El producto 2877 pertenece al bloque 1
# El producto 2878 pertenece al bloque 1
# El producto 2879 pertenece al bloque 1
# El producto 2880 pertenece al bloque 1
# El producto 2881 pertenece al bloque 1
# El producto 2882 pertenece al bloque 2
# El producto 2883 pertenece al bloque 1
# El producto 2884 pertenece al bloque 1
# El producto 2886 pertenece al bloque 1
# El producto 2887 pertenece al bloque 1
# El producto 2888 pertenece al bloque 1
# El producto 2889 pertenece al bloque 1
# El producto 2890 pertenece al bloque 1
# El producto 2891 pertenece al bloque 2
# El producto 2892 pertenece al bloque 1
# El producto 2893 pertenece al bloque 1
# El producto 2894 pertenece al bloque 2
# El producto 2895 pertenece al bloque 1
# El producto 2897 pertenece al bloque 1
# El producto 2898 pertenece al bloque 1
# El producto 2899 pertenece al bloque 1
# El producto 2900 pertenece al bloque 1
# El producto 2901 pertenece al bloque 1
# El producto 2902 pertenece al bloque 1
# El producto 2903 pertenece al bloque 2
# El producto 2904 pertenece al bloque 2
# El producto 2905 pertenece al bloque 2
# El producto 2906 pertenece al bloque 1
# El producto 2907 pertenece al bloque 2
# El producto 2908 pertenece al bloque 1
# El producto 2909 pertenece al bloque 2
# El producto 2910 pertenece al bloque 1
# El producto 2911 pertenece al bloque 2
# El producto 2912 pertenece al bloque 1
# El producto 2913 pertenece al bloque 1
# El producto 2914 pertenece al bloque 1
# El producto 2915 pertenece al bloque 1
# El producto 2916 pertenece al bloque 2
# El producto 2917 pertenece al bloque 1
# El producto 2918 pertenece al bloque 2
# El producto 2919 pertenece al bloque 1
# El producto 2920 pertenece al bloque 1
# El producto 2921 pertenece al bloque 1
# El producto 2922 pertenece al bloque 1
# El producto 2923 pertenece al bloque 1
# El producto 2924 pertenece al bloque 2
# El producto 2925 pertenece al bloque 1
# El producto 2926 pertenece al bloque 1
# El producto 2927 pertenece al bloque 1
# El producto 2928 pertenece al bloque 1
# El producto 2929 pertenece al bloque 1
# El producto 2930 pertenece al bloque 2
# El producto 2931 pertenece al bloque 1
# El producto 2932 pertenece al bloque 1
# El producto 2933 pertenece al bloque 1
# El producto 2934 pertenece al bloque 2
# El producto 2935 pertenece al bloque 1
# El producto 2936 pertenece al bloque 1
# El producto 2937 pertenece al bloque 1
# El producto 2938 pertenece al bloque 1
# El producto 2940 pertenece al bloque 1
# El producto 2941 pertenece al bloque 1
# El producto 2942 pertenece al bloque 1
# El producto 2943 pertenece al bloque 1
# El producto 2944 pertenece al bloque 1
# El producto 2945 pertenece al bloque 1
# El producto 2946 pertenece al bloque 1
# El producto 2947 pertenece al bloque 2
# El producto 2948 pertenece al bloque 1
# El producto 2949 pertenece al bloque 1
# El producto 2950 pertenece al bloque 1
# El producto 2951 pertenece al bloque 1
# El producto 2952 pertenece al bloque 1
# El producto 2953 pertenece al bloque 2
# El producto 2954 pertenece al bloque 1
# El producto 2955 pertenece al bloque 1
# El producto 2956 pertenece al bloque 1
# El producto 2957 pertenece al bloque 1
# El producto 2958 pertenece al bloque 2
# El producto 2959 pertenece al bloque 1
# El producto 2960 pertenece al bloque 2
# El producto 2961 pertenece al bloque 1
# El producto 2962 pertenece al bloque 1
# El producto 2964 pertenece al bloque 1
# El producto 2965 pertenece al bloque 2
# El producto 2966 pertenece al bloque 1
# El producto 2967 pertenece al bloque 2
# El producto 2968 pertenece al bloque 2
# El producto 2970 pertenece al bloque 2
# El producto 2971 pertenece al bloque 1
# El producto 2972 pertenece al bloque 1
# El producto 2973 pertenece al bloque 1
# El producto 2974 pertenece al bloque 1
# El producto 2975 pertenece al bloque 2
# El producto 2976 pertenece al bloque 1
# El producto 2977 pertenece al bloque 1
# El producto 2978 pertenece al bloque 2
# El producto 2979 pertenece al bloque 1
# El producto 2980 pertenece al bloque 1
# El producto 2981 pertenece al bloque 1
# El producto 2982 pertenece al bloque 1
# El producto 2983 pertenece al bloque 1
# El producto 2984 pertenece al bloque 1
# El producto 2985 pertenece al bloque 1
# El producto 2986 pertenece al bloque 2
# El producto 2987 pertenece al bloque 1
# El producto 2988 pertenece al bloque 1
# El producto 2989 pertenece al bloque 1
# El producto 2990 pertenece al bloque 1
# El producto 2991 pertenece al bloque 1
# El producto 2992 pertenece al bloque 1
# El producto 2993 pertenece al bloque 1
# El producto 2994 pertenece al bloque 1
# El producto 2995 pertenece al bloque 1
# El producto 2996 pertenece al bloque 1
# El producto 2997 pertenece al bloque 1
# El producto 2998 pertenece al bloque 1
# El producto 2999 pertenece al bloque 1
# El producto 3000 pertenece al bloque 1
# El producto 3001 pertenece al bloque 2
# El producto 3002 pertenece al bloque 2
# El producto 3003 pertenece al bloque 1
# El producto 3004 pertenece al bloque 1
# El producto 3005 pertenece al bloque 2
# El producto 3007 pertenece al bloque 1
# El producto 3008 pertenece al bloque 2
# El producto 3009 pertenece al bloque 1
# El producto 3010 pertenece al bloque 2
# El producto 3011 pertenece al bloque 1
# El producto 3012 pertenece al bloque 1
# El producto 3013 pertenece al bloque 1
# El producto 3014 pertenece al bloque 2
# El producto 3015 pertenece al bloque 2
# El producto 3016 pertenece al bloque 1
# El producto 3017 pertenece al bloque 1
# El producto 3018 pertenece al bloque 1
# El producto 3019 pertenece al bloque 1
# El producto 3020 pertenece al bloque 1
# El producto 3021 pertenece al bloque 1
# El producto 3023 pertenece al bloque 1
# El producto 3024 pertenece al bloque 2
# El producto 3025 pertenece al bloque 1
# El producto 3026 pertenece al bloque 2
# El producto 3027 pertenece al bloque 2
# El producto 3028 pertenece al bloque 1
# El producto 3029 pertenece al bloque 1
# El producto 3030 pertenece al bloque 1
# El producto 3031 pertenece al bloque 1
# El producto 3032 pertenece al bloque 1
# El producto 3033 pertenece al bloque 1
# El producto 3034 pertenece al bloque 1
# El producto 3035 pertenece al bloque 1
# El producto 3036 pertenece al bloque 1
# El producto 3037 pertenece al bloque 1
# El producto 3038 pertenece al bloque 2
# El producto 3039 pertenece al bloque 1
# El producto 3040 pertenece al bloque 2
# El producto 3041 pertenece al bloque 1
# El producto 3042 pertenece al bloque 1
# El producto 3043 pertenece al bloque 1
# El producto 3044 pertenece al bloque 1
# El producto 3045 pertenece al bloque 2
# El producto 3046 pertenece al bloque 1
# El producto 3047 pertenece al bloque 2
# El producto 3048 pertenece al bloque 1
# El producto 3049 pertenece al bloque 1
# El producto 3050 pertenece al bloque 2
# El producto 3051 pertenece al bloque 1
# El producto 3052 pertenece al bloque 1
# El producto 3053 pertenece al bloque 1
# El producto 3054 pertenece al bloque 2
# El producto 3055 pertenece al bloque 1
# El producto 3056 pertenece al bloque 1
# El producto 3057 pertenece al bloque 1
# El producto 3058 pertenece al bloque 1
# El producto 3060 pertenece al bloque 1
# El producto 3061 pertenece al bloque 2
# El producto 3062 pertenece al bloque 1
# El producto 3063 pertenece al bloque 2
# El producto 3064 pertenece al bloque 1
# El producto 3065 pertenece al bloque 1
# El producto 3066 pertenece al bloque 1
# El producto 3067 pertenece al bloque 1
# El producto 3068 pertenece al bloque 1
# El producto 3069 pertenece al bloque 1
# El producto 3070 pertenece al bloque 2
# El producto 3071 pertenece al bloque 2
# El producto 3072 pertenece al bloque 2
# El producto 3073 pertenece al bloque 2
# El producto 3074 pertenece al bloque 1
# El producto 3075 pertenece al bloque 1
# El producto 3077 pertenece al bloque 1
# El producto 3078 pertenece al bloque 1
# El producto 3079 pertenece al bloque 1
# El producto 3080 pertenece al bloque 1
# El producto 3081 pertenece al bloque 2
# El producto 3082 pertenece al bloque 1
# El producto 3083 pertenece al bloque 1
# El producto 3084 pertenece al bloque 2
# El producto 3085 pertenece al bloque 1
# El producto 3086 pertenece al bloque 1
# El producto 3087 pertenece al bloque 1
# El producto 3088 pertenece al bloque 1
# El producto 3089 pertenece al bloque 1
# El producto 3090 pertenece al bloque 1
# El producto 3091 pertenece al bloque 1
# El producto 3092 pertenece al bloque 1
# El producto 3093 pertenece al bloque 2
# El producto 3094 pertenece al bloque 1
# El producto 3095 pertenece al bloque 1
# El producto 3096 pertenece al bloque 1
# El producto 3097 pertenece al bloque 2
# El producto 3099 pertenece al bloque 2
# El producto 3100 pertenece al bloque 1
# El producto 3101 pertenece al bloque 1
# El producto 3102 pertenece al bloque 1
# El producto 3104 pertenece al bloque 2
# El producto 3105 pertenece al bloque 1
# El producto 3106 pertenece al bloque 1
# El producto 3107 pertenece al bloque 1
# El producto 3108 pertenece al bloque 1
# El producto 3109 pertenece al bloque 2
# El producto 3110 pertenece al bloque 1
# El producto 3111 pertenece al bloque 1
# El producto 3112 pertenece al bloque 2
# El producto 3113 pertenece al bloque 1
# El producto 3114 pertenece al bloque 1
# El producto 3115 pertenece al bloque 1
# El producto 3116 pertenece al bloque 2
# El producto 3117 pertenece al bloque 1
# El producto 3118 pertenece al bloque 1
# El producto 3119 pertenece al bloque 1
# El producto 3120 pertenece al bloque 1
# El producto 3121 pertenece al bloque 1
# El producto 3122 pertenece al bloque 1
# El producto 3123 pertenece al bloque 1
# El producto 3124 pertenece al bloque 2
# El producto 3125 pertenece al bloque 1
# El producto 3126 pertenece al bloque 2
# El producto 3127 pertenece al bloque 1
# El producto 3128 pertenece al bloque 2
# El producto 3129 pertenece al bloque 1
# El producto 3130 pertenece al bloque 1
# El producto 3131 pertenece al bloque 1
# El producto 3132 pertenece al bloque 2
# El producto 3133 pertenece al bloque 1
# El producto 3134 pertenece al bloque 1
# El producto 3135 pertenece al bloque 1
# El producto 3136 pertenece al bloque 1
# El producto 3137 pertenece al bloque 1
# El producto 3138 pertenece al bloque 2
# El producto 3139 pertenece al bloque 1
# El producto 3140 pertenece al bloque 1
# El producto 3141 pertenece al bloque 2
# El producto 3142 pertenece al bloque 1
# El producto 3143 pertenece al bloque 1
# El producto 3144 pertenece al bloque 1
# El producto 3145 pertenece al bloque 1
# El producto 3146 pertenece al bloque 1
# El producto 3147 pertenece al bloque 1
# El producto 3148 pertenece al bloque 1
# El producto 3149 pertenece al bloque 1
# El producto 3150 pertenece al bloque 2
# El producto 3151 pertenece al bloque 1
# El producto 3152 pertenece al bloque 1
# El producto 3153 pertenece al bloque 1
# El producto 3154 pertenece al bloque 1
# El producto 3155 pertenece al bloque 1
# El producto 3156 pertenece al bloque 1
# El producto 3157 pertenece al bloque 1
# El producto 3158 pertenece al bloque 1
# El producto 3159 pertenece al bloque 1
# El producto 3160 pertenece al bloque 2
# El producto 3161 pertenece al bloque 1
# El producto 3162 pertenece al bloque 1
# El producto 3163 pertenece al bloque 2
# El producto 3164 pertenece al bloque 1
# El producto 3165 pertenece al bloque 1
# El producto 3166 pertenece al bloque 1
# El producto 3167 pertenece al bloque 1
# El producto 3168 pertenece al bloque 1
# El producto 3169 pertenece al bloque 1
# El producto 3170 pertenece al bloque 1
# El producto 3171 pertenece al bloque 1
# El producto 3172 pertenece al bloque 1
# El producto 3173 pertenece al bloque 1
# El producto 3174 pertenece al bloque 1
# El producto 3175 pertenece al bloque 1
# El producto 3176 pertenece al bloque 1
# El producto 3177 pertenece al bloque 1
# El producto 3178 pertenece al bloque 1
# El producto 3179 pertenece al bloque 1
# El producto 3180 pertenece al bloque 1
# El producto 3181 pertenece al bloque 1
# El producto 3182 pertenece al bloque 2
# El producto 3183 pertenece al bloque 1
# El producto 3184 pertenece al bloque 1
# El producto 3185 pertenece al bloque 1
# El producto 3186 pertenece al bloque 1
# El producto 3187 pertenece al bloque 1
# El producto 3188 pertenece al bloque 1
# El producto 3189 pertenece al bloque 2
# El producto 3190 pertenece al bloque 1
# El producto 3191 pertenece al bloque 1
# El producto 3192 pertenece al bloque 1
# El producto 3193 pertenece al bloque 1
# El producto 3194 pertenece al bloque 1
# El producto 3195 pertenece al bloque 2
# El producto 3196 pertenece al bloque 1
# El producto 3197 pertenece al bloque 1
# El producto 3198 pertenece al bloque 1
# El producto 3199 pertenece al bloque 1
# El producto 3200 pertenece al bloque 2
# El producto 3201 pertenece al bloque 2
# El producto 3202 pertenece al bloque 1
# El producto 3203 pertenece al bloque 1
# El producto 3204 pertenece al bloque 2
# El producto 3205 pertenece al bloque 1
# El producto 3206 pertenece al bloque 1
# El producto 3207 pertenece al bloque 1
# El producto 3208 pertenece al bloque 1
# El producto 3209 pertenece al bloque 1
# El producto 3210 pertenece al bloque 1
# El producto 3211 pertenece al bloque 1
# El producto 3212 pertenece al bloque 1
# El producto 3213 pertenece al bloque 1
# El producto 3214 pertenece al bloque 1
# El producto 3215 pertenece al bloque 1
# El producto 3216 pertenece al bloque 1
# El producto 3217 pertenece al bloque 1
# El producto 3218 pertenece al bloque 1
# El producto 3219 pertenece al bloque 1
# El producto 3221 pertenece al bloque 2
# El producto 3222 pertenece al bloque 1
# El producto 3223 pertenece al bloque 1
# El producto 3224 pertenece al bloque 1
# El producto 3225 pertenece al bloque 1
# El producto 3226 pertenece al bloque 1
# El producto 3227 pertenece al bloque 2
# El producto 3228 pertenece al bloque 1
# El producto 3229 pertenece al bloque 1
# El producto 3230 pertenece al bloque 1
# El producto 3232 pertenece al bloque 2
# El producto 3233 pertenece al bloque 1
# El producto 3234 pertenece al bloque 1
# El producto 3235 pertenece al bloque 2
# El producto 3236 pertenece al bloque 1
# El producto 3237 pertenece al bloque 1
# El producto 3238 pertenece al bloque 1
# El producto 3239 pertenece al bloque 1
# El producto 3240 pertenece al bloque 2
# El producto 3241 pertenece al bloque 1
# El producto 3242 pertenece al bloque 1
# El producto 3243 pertenece al bloque 1
# El producto 3244 pertenece al bloque 1
# El producto 3245 pertenece al bloque 1
# El producto 3246 pertenece al bloque 1
# El producto 3247 pertenece al bloque 1
# El producto 3248 pertenece al bloque 1
# El producto 3249 pertenece al bloque 1
# El producto 3250 pertenece al bloque 1
# El producto 3251 pertenece al bloque 1
# El producto 3252 pertenece al bloque 1
# El producto 3253 pertenece al bloque 2
# El producto 3254 pertenece al bloque 1
# El producto 3255 pertenece al bloque 1
# El producto 3256 pertenece al bloque 1
# El producto 3257 pertenece al bloque 2
# El producto 3258 pertenece al bloque 1
# El producto 3259 pertenece al bloque 1
# El producto 3260 pertenece al bloque 1
# El producto 3261 pertenece al bloque 1
# El producto 3262 pertenece al bloque 1
# El producto 3263 pertenece al bloque 1
# El producto 3264 pertenece al bloque 1
# El producto 3265 pertenece al bloque 1
# El producto 3266 pertenece al bloque 1
# El producto 3267 pertenece al bloque 1
# El producto 3268 pertenece al bloque 2
# El producto 3269 pertenece al bloque 1
# El producto 3270 pertenece al bloque 1
# El producto 3271 pertenece al bloque 1
# El producto 3272 pertenece al bloque 1
# El producto 3273 pertenece al bloque 2
# El producto 3274 pertenece al bloque 1
# El producto 3275 pertenece al bloque 2
# El producto 3276 pertenece al bloque 1
# El producto 3277 pertenece al bloque 1
# El producto 3278 pertenece al bloque 1
# El producto 3279 pertenece al bloque 1
# El producto 3280 pertenece al bloque 1
# El producto 3281 pertenece al bloque 1
# El producto 3282 pertenece al bloque 1
# El producto 3283 pertenece al bloque 1
# El producto 3284 pertenece al bloque 1
# El producto 3285 pertenece al bloque 1
# El producto 3286 pertenece al bloque 2
# El producto 3287 pertenece al bloque 1
# El producto 3288 pertenece al bloque 1
# El producto 3289 pertenece al bloque 1
# El producto 3290 pertenece al bloque 2
# El producto 3291 pertenece al bloque 1
# El producto 3292 pertenece al bloque 1
# El producto 3293 pertenece al bloque 1
# El producto 3294 pertenece al bloque 1
# El producto 3295 pertenece al bloque 1
# El producto 3296 pertenece al bloque 2
# El producto 3297 pertenece al bloque 1
# El producto 3298 pertenece al bloque 1
# El producto 3299 pertenece al bloque 1
# El producto 3300 pertenece al bloque 1
# El producto 3301 pertenece al bloque 1
# El producto 3302 pertenece al bloque 1
# El producto 3303 pertenece al bloque 1
# El producto 3304 pertenece al bloque 2
# El producto 3305 pertenece al bloque 1
# El producto 3306 pertenece al bloque 1
# El producto 3307 pertenece al bloque 1
# El producto 3308 pertenece al bloque 1
# El producto 3309 pertenece al bloque 2
# El producto 3310 pertenece al bloque 2
# El producto 3311 pertenece al bloque 2
# El producto 3312 pertenece al bloque 1
# El producto 3313 pertenece al bloque 1
# El producto 3314 pertenece al bloque 1
# El producto 3315 pertenece al bloque 2
# El producto 3317 pertenece al bloque 1
# El producto 3318 pertenece al bloque 2
# El producto 3319 pertenece al bloque 1
# El producto 3320 pertenece al bloque 1
# El producto 3321 pertenece al bloque 1
# El producto 3322 pertenece al bloque 2
# El producto 3323 pertenece al bloque 2
# El producto 3324 pertenece al bloque 1
# El producto 3325 pertenece al bloque 1
# El producto 3326 pertenece al bloque 1
# El producto 3327 pertenece al bloque 1
# El producto 3328 pertenece al bloque 1
# El producto 3329 pertenece al bloque 1
# El producto 3330 pertenece al bloque 1
# El producto 3331 pertenece al bloque 2
# El producto 3332 pertenece al bloque 1
# El producto 3333 pertenece al bloque 1
# El producto 3334 pertenece al bloque 2
# El producto 3335 pertenece al bloque 1
# El producto 3336 pertenece al bloque 1
# El producto 3337 pertenece al bloque 1
# El producto 3338 pertenece al bloque 2
# El producto 3339 pertenece al bloque 1
# El producto 3340 pertenece al bloque 1
# El producto 3341 pertenece al bloque 1
# El producto 3342 pertenece al bloque 1
# El producto 3343 pertenece al bloque 1
# El producto 3344 pertenece al bloque 1
# El producto 3345 pertenece al bloque 1
# El producto 3346 pertenece al bloque 1
# El producto 3347 pertenece al bloque 2
# El producto 3348 pertenece al bloque 1
# El producto 3349 pertenece al bloque 1
# El producto 3350 pertenece al bloque 1
# El producto 3351 pertenece al bloque 1
# El producto 3352 pertenece al bloque 1
# El producto 3353 pertenece al bloque 1
# El producto 3354 pertenece al bloque 1
# El producto 3355 pertenece al bloque 1
# El producto 3356 pertenece al bloque 1
# El producto 3357 pertenece al bloque 1
# El producto 3358 pertenece al bloque 1
# El producto 3359 pertenece al bloque 1
# El producto 3360 pertenece al bloque 1
# El producto 3361 pertenece al bloque 2
# El producto 3362 pertenece al bloque 1
# El producto 3363 pertenece al bloque 2
# El producto 3364 pertenece al bloque 2
# El producto 3365 pertenece al bloque 1
# El producto 3366 pertenece al bloque 1
# El producto 3367 pertenece al bloque 2
# El producto 3368 pertenece al bloque 2
# El producto 3369 pertenece al bloque 1
# El producto 3370 pertenece al bloque 1
# El producto 3371 pertenece al bloque 2
# El producto 3372 pertenece al bloque 1
# El producto 3373 pertenece al bloque 1
# El producto 3374 pertenece al bloque 2
# El producto 3375 pertenece al bloque 1
# El producto 3376 pertenece al bloque 1
# El producto 3377 pertenece al bloque 2
# El producto 3378 pertenece al bloque 2
# El producto 3379 pertenece al bloque 1
# El producto 3380 pertenece al bloque 1
# El producto 3381 pertenece al bloque 1
# El producto 3382 pertenece al bloque 1
# El producto 3383 pertenece al bloque 2
# El producto 3384 pertenece al bloque 1
# El producto 3385 pertenece al bloque 2
# El producto 3386 pertenece al bloque 1
# El producto 3387 pertenece al bloque 1
# El producto 3388 pertenece al bloque 1
# El producto 3389 pertenece al bloque 1
# El producto 3390 pertenece al bloque 1
# El producto 3391 pertenece al bloque 2
# El producto 3392 pertenece al bloque 2
# El producto 3393 pertenece al bloque 1
# El producto 3394 pertenece al bloque 1
# El producto 3395 pertenece al bloque 1
# El producto 3396 pertenece al bloque 1
# El producto 3397 pertenece al bloque 1
# El producto 3398 pertenece al bloque 1
# El producto 3399 pertenece al bloque 1
# El producto 3400 pertenece al bloque 1
# El producto 3401 pertenece al bloque 1
# El producto 3402 pertenece al bloque 1
# El producto 3403 pertenece al bloque 1
# El producto 3404 pertenece al bloque 2
# El producto 3405 pertenece al bloque 2
# El producto 3406 pertenece al bloque 1
# El producto 3407 pertenece al bloque 1
# El producto 3408 pertenece al bloque 1
# El producto 3409 pertenece al bloque 1
# El producto 3410 pertenece al bloque 2
# El producto 3411 pertenece al bloque 1
# El producto 3412 pertenece al bloque 1
# El producto 3413 pertenece al bloque 1
# El producto 3414 pertenece al bloque 1
# El producto 3415 pertenece al bloque 1
# El producto 3416 pertenece al bloque 1
# El producto 3417 pertenece al bloque 1
# El producto 3418 pertenece al bloque 1
# El producto 3420 pertenece al bloque 1
# El producto 3421 pertenece al bloque 2
# El producto 3422 pertenece al bloque 1
# El producto 3423 pertenece al bloque 1
# El producto 3424 pertenece al bloque 2
# El producto 3425 pertenece al bloque 1
# El producto 3426 pertenece al bloque 1
# El producto 3427 pertenece al bloque 1
# El producto 3428 pertenece al bloque 1
# El producto 3429 pertenece al bloque 2
# El producto 3430 pertenece al bloque 1
# El producto 3432 pertenece al bloque 2
# El producto 3433 pertenece al bloque 2
# El producto 3434 pertenece al bloque 1
# El producto 3435 pertenece al bloque 1
# El producto 3436 pertenece al bloque 1
# El producto 3437 pertenece al bloque 1
# El producto 3438 pertenece al bloque 1
# El producto 3439 pertenece al bloque 1
# El producto 3440 pertenece al bloque 2
# El producto 3442 pertenece al bloque 1
# El producto 3443 pertenece al bloque 1
# El producto 3444 pertenece al bloque 1
# El producto 3445 pertenece al bloque 1
# El producto 3446 pertenece al bloque 2
# El producto 3447 pertenece al bloque 1
# El producto 3448 pertenece al bloque 2
# El producto 3449 pertenece al bloque 1
# El producto 3450 pertenece al bloque 1
# El producto 3451 pertenece al bloque 1
# El producto 3452 pertenece al bloque 1
# El producto 3453 pertenece al bloque 1
# El producto 3454 pertenece al bloque 2
# El producto 3455 pertenece al bloque 2
# El producto 3457 pertenece al bloque 1
# El producto 3458 pertenece al bloque 2
# El producto 3459 pertenece al bloque 1
# El producto 3460 pertenece al bloque 1
# El producto 3461 pertenece al bloque 1
# El producto 3462 pertenece al bloque 1
# El producto 3463 pertenece al bloque 1
# El producto 3464 pertenece al bloque 1
# El producto 3465 pertenece al bloque 1
# El producto 3466 pertenece al bloque 1
# El producto 3467 pertenece al bloque 2
# El producto 3468 pertenece al bloque 2
# El producto 3469 pertenece al bloque 1
# El producto 3470 pertenece al bloque 1
# El producto 3471 pertenece al bloque 1
# El producto 3472 pertenece al bloque 1
# El producto 3473 pertenece al bloque 1
# El producto 3474 pertenece al bloque 2
# El producto 3475 pertenece al bloque 1
# El producto 3476 pertenece al bloque 1
# El producto 3477 pertenece al bloque 1
# ...
# El producto 6962 pertenece al bloque 1
# El producto 6963 pertenece al bloque 1
# El producto 6964 pertenece al bloque 1
# El producto 6965 pertenece al bloque 1
# El producto 6966 pertenece al bloque 1
# El producto 6967 pertenece al bloque 1
# El producto 6968 pertenece al bloque 1
# El producto 6969 pertenece al bloque 1
# El producto 6970 pertenece al bloque 1
# El producto 6971 pertenece al bloque 1
# El producto 6972 pertenece al bloque 1
# El producto 6973 pertenece al bloque 1
# El producto 6974 pertenece al bloque 1
# El producto 6975 pertenece al bloque 1
# El producto 6976 pertenece al bloque 2
# El producto 6977 pertenece al bloque 2
# El producto 6978 pertenece al bloque 2
# El producto 6979 pertenece al bloque 1
# El producto 6980 pertenece al bloque 1
# El producto 6981 pertenece al bloque 1
# El producto 6982 pertenece al bloque 1
# El producto 6983 pertenece al bloque 1
# El producto 6984 pertenece al bloque 1
# El producto 6985 pertenece al bloque 2
# El producto 6986 pertenece al bloque 1
# El producto 6987 pertenece al bloque 1
# El producto 6988 pertenece al bloque 1
# El producto 6989 pertenece al bloque 1
# El producto 6990 pertenece al bloque 1
# El producto 6991 pertenece al bloque 1
# El producto 6992 pertenece al bloque 2
# El producto 6993 pertenece al bloque 1
# El producto 6994 pertenece al bloque 2
# El producto 6995 pertenece al bloque 1
# El producto 6996 pertenece al bloque 1
# El producto 6997 pertenece al bloque 1
# El producto 6998 pertenece al bloque 1
# El producto 6999 pertenece al bloque 1
# El producto 7000 pertenece al bloque 2
# El producto 7001 pertenece al bloque 2
# El producto 7002 pertenece al bloque 1
# El producto 7003 pertenece al bloque 2
# El producto 7004 pertenece al bloque 1
# El producto 7005 pertenece al bloque 2
# El producto 7006 pertenece al bloque 2
# El producto 7007 pertenece al bloque 1
# El producto 7008 pertenece al bloque 1
# El producto 7009 pertenece al bloque 1
# El producto 7010 pertenece al bloque 1
# El producto 7011 pertenece al bloque 1
# El producto 7012 pertenece al bloque 1
# El producto 7013 pertenece al bloque 1
# El producto 7014 pertenece al bloque 1
# El producto 7015 pertenece al bloque 1
# El producto 7016 pertenece al bloque 1
# El producto 7017 pertenece al bloque 2
# El producto 7018 pertenece al bloque 2
# El producto 7019 pertenece al bloque 1
# El producto 7020 pertenece al bloque 1
# El producto 7021 pertenece al bloque 1
# El producto 7022 pertenece al bloque 2
# El producto 7023 pertenece al bloque 1
# El producto 7024 pertenece al bloque 1
# El producto 7025 pertenece al bloque 1
# El producto 7026 pertenece al bloque 1
# El producto 7027 pertenece al bloque 1
# El producto 7028 pertenece al bloque 1
# El producto 7029 pertenece al bloque 1
# El producto 7030 pertenece al bloque 1
# El producto 7031 pertenece al bloque 1
# El producto 7032 pertenece al bloque 1
# El producto 7033 pertenece al bloque 2
# El producto 7034 pertenece al bloque 1
# El producto 7035 pertenece al bloque 1
# El producto 7036 pertenece al bloque 1
# El producto 7037 pertenece al bloque 1
# El producto 7038 pertenece al bloque 1
# El producto 7039 pertenece al bloque 1
# El producto 7040 pertenece al bloque 1
# El producto 7041 pertenece al bloque 1
# El producto 7042 pertenece al bloque 1
# El producto 7043 pertenece al bloque 1
# El producto 7044 pertenece al bloque 1
# El producto 7045 pertenece al bloque 1
# El producto 7046 pertenece al bloque 2
# El producto 7047 pertenece al bloque 1
# El producto 7048 pertenece al bloque 1
# El producto 7049 pertenece al bloque 1
# El producto 7050 pertenece al bloque 1
# El producto 7051 pertenece al bloque 1
# El producto 7052 pertenece al bloque 1
# El producto 7053 pertenece al bloque 1
# El producto 7054 pertenece al bloque 1
# El producto 7055 pertenece al bloque 2
# El producto 7056 pertenece al bloque 1
# El producto 7057 pertenece al bloque 1
# El producto 7058 pertenece al bloque 2
# El producto 7059 pertenece al bloque 2
# El producto 7060 pertenece al bloque 1
# El producto 7061 pertenece al bloque 2
# El producto 7062 pertenece al bloque 1
# El producto 7063 pertenece al bloque 1
# El producto 7064 pertenece al bloque 2
# El producto 7065 pertenece al bloque 2
# El producto 7066 pertenece al bloque 2
# El producto 7067 pertenece al bloque 1
# El producto 7068 pertenece al bloque 2
# El producto 7069 pertenece al bloque 1
# El producto 7070 pertenece al bloque 1
# El producto 7071 pertenece al bloque 1
# El producto 7072 pertenece al bloque 1
# El producto 7073 pertenece al bloque 1
# El producto 7074 pertenece al bloque 1
# El producto 7075 pertenece al bloque 1
# El producto 7076 pertenece al bloque 1
# El producto 7078 pertenece al bloque 1
# El producto 7079 pertenece al bloque 2
# El producto 7080 pertenece al bloque 1
# El producto 7081 pertenece al bloque 2
# El producto 7082 pertenece al bloque 1
# El producto 7083 pertenece al bloque 2
# El producto 7084 pertenece al bloque 1
# El producto 7085 pertenece al bloque 1
# El producto 7086 pertenece al bloque 2
# El producto 7087 pertenece al bloque 2
# El producto 7088 pertenece al bloque 1
# El producto 7089 pertenece al bloque 2
# El producto 7090 pertenece al bloque 1
# El producto 7091 pertenece al bloque 1
# El producto 7092 pertenece al bloque 1
# El producto 7093 pertenece al bloque 1
# El producto 7094 pertenece al bloque 1
# El producto 7095 pertenece al bloque 1
# El producto 7096 pertenece al bloque 1
# El producto 7097 pertenece al bloque 1
# El producto 7098 pertenece al bloque 1
# El producto 7099 pertenece al bloque 1
# El producto 7100 pertenece al bloque 1
# El producto 7101 pertenece al bloque 1
# El producto 7102 pertenece al bloque 2
# El producto 7103 pertenece al bloque 1
# El producto 7104 pertenece al bloque 1
# El producto 7105 pertenece al bloque 1
# El producto 7106 pertenece al bloque 1
# El producto 7107 pertenece al bloque 2
# El producto 7108 pertenece al bloque 1
# El producto 7109 pertenece al bloque 1
# El producto 7110 pertenece al bloque 1
# El producto 7111 pertenece al bloque 1
# El producto 7112 pertenece al bloque 1
# El producto 7113 pertenece al bloque 1
# El producto 7114 pertenece al bloque 1
# El producto 7115 pertenece al bloque 1
# El producto 7116 pertenece al bloque 1
# El producto 7117 pertenece al bloque 1
# El producto 7118 pertenece al bloque 1
# El producto 7119 pertenece al bloque 1
# El producto 7120 pertenece al bloque 1
# El producto 7121 pertenece al bloque 1
# El producto 7122 pertenece al bloque 1
# El producto 7123 pertenece al bloque 1
# El producto 7124 pertenece al bloque 1
# El producto 7125 pertenece al bloque 1
# El producto 7126 pertenece al bloque 1
# El producto 7127 pertenece al bloque 1
# El producto 7128 pertenece al bloque 1
# El producto 7129 pertenece al bloque 1
# El producto 7130 pertenece al bloque 2
# El producto 7131 pertenece al bloque 1
# El producto 7132 pertenece al bloque 1
# El producto 7133 pertenece al bloque 1
# El producto 7134 pertenece al bloque 1
# El producto 7135 pertenece al bloque 1
# El producto 7136 pertenece al bloque 0
# El producto 7137 pertenece al bloque 1
# El producto 7138 pertenece al bloque 1
# El producto 7139 pertenece al bloque 1
# El producto 7140 pertenece al bloque 1
# El producto 7141 pertenece al bloque 1
# El producto 7142 pertenece al bloque 1
# El producto 7143 pertenece al bloque 1
# El producto 7144 pertenece al bloque 1
# El producto 7145 pertenece al bloque 1
# El producto 7146 pertenece al bloque 1
# El producto 7147 pertenece al bloque 1
# El producto 7148 pertenece al bloque 1
# El producto 7149 pertenece al bloque 1
# El producto 7150 pertenece al bloque 1
# El producto 7151 pertenece al bloque 1
# El producto 7152 pertenece al bloque 1
# El producto 7153 pertenece al bloque 1
# El producto 7154 pertenece al bloque 1
# El producto 7155 pertenece al bloque 2
# El producto 7156 pertenece al bloque 1
# El producto 7157 pertenece al bloque 1
# El producto 7158 pertenece al bloque 0
# El producto 7159 pertenece al bloque 1
# El producto 7160 pertenece al bloque 1
# El producto 7161 pertenece al bloque 1
# El producto 7162 pertenece al bloque 1
# El producto 7163 pertenece al bloque 2
# El producto 7164 pertenece al bloque 1
# El producto 7165 pertenece al bloque 1
# El producto 7166 pertenece al bloque 1
# El producto 7167 pertenece al bloque 1
# El producto 7168 pertenece al bloque 2
# El producto 7169 pertenece al bloque 1
# El producto 7170 pertenece al bloque 1
# El producto 7171 pertenece al bloque 1
# El producto 7172 pertenece al bloque 1
# El producto 7173 pertenece al bloque 1
# El producto 7174 pertenece al bloque 1
# El producto 7175 pertenece al bloque 1
# El producto 7176 pertenece al bloque 2
# El producto 7177 pertenece al bloque 2
# El producto 7178 pertenece al bloque 1
# El producto 7179 pertenece al bloque 0
# El producto 7180 pertenece al bloque 1
# El producto 7181 pertenece al bloque 1
# El producto 7182 pertenece al bloque 0
# El producto 7183 pertenece al bloque 1
# El producto 7184 pertenece al bloque 1
# El producto 7185 pertenece al bloque 1
# El producto 7186 pertenece al bloque 1
# El producto 7187 pertenece al bloque 1
# El producto 7188 pertenece al bloque 1
# El producto 7189 pertenece al bloque 1
# El producto 7190 pertenece al bloque 1
# El producto 7191 pertenece al bloque 1
# El producto 7192 pertenece al bloque 1
# El producto 7193 pertenece al bloque 1
# El producto 7194 pertenece al bloque 2
# El producto 7195 pertenece al bloque 1
# El producto 7196 pertenece al bloque 1
# El producto 7197 pertenece al bloque 1
# El producto 7198 pertenece al bloque 1
# El producto 7199 pertenece al bloque 1
# El producto 7200 pertenece al bloque 1
# El producto 7201 pertenece al bloque 1
# El producto 7202 pertenece al bloque 1
# El producto 7203 pertenece al bloque 1
# El producto 7204 pertenece al bloque 1
# El producto 7205 pertenece al bloque 1
# El producto 7206 pertenece al bloque 1
# El producto 7207 pertenece al bloque 2
# El producto 7208 pertenece al bloque 1
# El producto 7209 pertenece al bloque 1
# El producto 7210 pertenece al bloque 1
# El producto 7211 pertenece al bloque 2
# El producto 7212 pertenece al bloque 2
# El producto 7213 pertenece al bloque 1
# El producto 7214 pertenece al bloque 1
# El producto 7215 pertenece al bloque 1
# El producto 7216 pertenece al bloque 2
# El producto 7217 pertenece al bloque 1
# El producto 7218 pertenece al bloque 1
# El producto 7219 pertenece al bloque 1
# El producto 7220 pertenece al bloque 1
# El producto 7221 pertenece al bloque 1
# El producto 7223 pertenece al bloque 1
# El producto 7224 pertenece al bloque 1
# El producto 7225 pertenece al bloque 1
# El producto 7226 pertenece al bloque 2
# El producto 7227 pertenece al bloque 1
# El producto 7228 pertenece al bloque 1
# El producto 7229 pertenece al bloque 2
# El producto 7230 pertenece al bloque 1
# El producto 7231 pertenece al bloque 2
# El producto 7232 pertenece al bloque 1
# El producto 7233 pertenece al bloque 1
# El producto 7234 pertenece al bloque 1
# El producto 7235 pertenece al bloque 1
# El producto 7236 pertenece al bloque 1
# El producto 7237 pertenece al bloque 1
# El producto 7238 pertenece al bloque 2
# El producto 7240 pertenece al bloque 1
# El producto 7241 pertenece al bloque 1
# El producto 7242 pertenece al bloque 1
# El producto 7243 pertenece al bloque 1
# El producto 7244 pertenece al bloque 2
# El producto 7245 pertenece al bloque 1
# El producto 7247 pertenece al bloque 1
# El producto 7248 pertenece al bloque 1
# El producto 7249 pertenece al bloque 1
# El producto 7250 pertenece al bloque 2
# El producto 7251 pertenece al bloque 1
# El producto 7252 pertenece al bloque 1
# El producto 7253 pertenece al bloque 1
# El producto 7254 pertenece al bloque 2
# El producto 7255 pertenece al bloque 1
# El producto 7256 pertenece al bloque 1
# El producto 7257 pertenece al bloque 1
# El producto 7258 pertenece al bloque 1
# El producto 7259 pertenece al bloque 1
# El producto 7260 pertenece al bloque 1
# El producto 7261 pertenece al bloque 1
# El producto 7262 pertenece al bloque 1
# El producto 7263 pertenece al bloque 1
# El producto 7264 pertenece al bloque 1
# El producto 7265 pertenece al bloque 1
# El producto 7266 pertenece al bloque 1
# El producto 7267 pertenece al bloque 1
# El producto 7268 pertenece al bloque 1
# El producto 7269 pertenece al bloque 1
# El producto 7270 pertenece al bloque 2
# El producto 7272 pertenece al bloque 1
# El producto 7273 pertenece al bloque 1
# El producto 7274 pertenece al bloque 1
# El producto 7275 pertenece al bloque 1
# El producto 7276 pertenece al bloque 2
# El producto 7277 pertenece al bloque 1
# El producto 7278 pertenece al bloque 1
# El producto 7279 pertenece al bloque 1
# El producto 7280 pertenece al bloque 1
# El producto 7281 pertenece al bloque 1
# El producto 7282 pertenece al bloque 1
# El producto 7283 pertenece al bloque 1
# El producto 7284 pertenece al bloque 1
# El producto 7285 pertenece al bloque 1
# El producto 7286 pertenece al bloque 1
# El producto 7287 pertenece al bloque 1
# El producto 7288 pertenece al bloque 1
# El producto 7289 pertenece al bloque 2
# El producto 7290 pertenece al bloque 1
# El producto 7291 pertenece al bloque 1
# El producto 7292 pertenece al bloque 1
# El producto 7293 pertenece al bloque 1
# El producto 7294 pertenece al bloque 2
# El producto 7295 pertenece al bloque 1
# El producto 7296 pertenece al bloque 1
# El producto 7297 pertenece al bloque 1
# El producto 7298 pertenece al bloque 1
# El producto 7299 pertenece al bloque 1
# El producto 7300 pertenece al bloque 1
# El producto 7301 pertenece al bloque 0
# El producto 7302 pertenece al bloque 1
# El producto 7304 pertenece al bloque 1
# El producto 7305 pertenece al bloque 1
# El producto 7306 pertenece al bloque 1
# El producto 7307 pertenece al bloque 2
# El producto 7308 pertenece al bloque 2
# El producto 7309 pertenece al bloque 1
# El producto 7310 pertenece al bloque 1
# El producto 7311 pertenece al bloque 1
# El producto 7312 pertenece al bloque 1
# El producto 7313 pertenece al bloque 1
# El producto 7314 pertenece al bloque 1
# El producto 7315 pertenece al bloque 1
# El producto 7316 pertenece al bloque 1
# El producto 7317 pertenece al bloque 1
# El producto 7318 pertenece al bloque 2
# El producto 7319 pertenece al bloque 1
# El producto 7320 pertenece al bloque 1
# El producto 7321 pertenece al bloque 1
# El producto 7322 pertenece al bloque 0
# El producto 7323 pertenece al bloque 1
# El producto 7324 pertenece al bloque 1
# El producto 7325 pertenece al bloque 1
# El producto 7326 pertenece al bloque 1
# El producto 7327 pertenece al bloque 1
# El producto 7328 pertenece al bloque 2
# El producto 7329 pertenece al bloque 0
# El producto 7330 pertenece al bloque 1
# El producto 7331 pertenece al bloque 1
# El producto 7332 pertenece al bloque 1
# Medoides originales (clusters de referencia):
#            Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# Cluster A             4.449562         1.001030           253.270129
# Cluster B             3.432319         3.719437           192.985053
# Cluster C             4.617830         1.051206           243.202633
#
#            Prior_purchases  Discount_offered  Weight_in_gms
# Cluster A         5.269662          1.012622    1381.870639
# Cluster B         5.262020          4.812524    1425.684728
# Cluster C         5.050843          2.675291    1670.335695
# Medoides tras la integración:
#            Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# Cluster A             4.893701         1.130426           256.791361
# Cluster B             3.490683         3.849612           194.302601
# Cluster C             4.485097         1.067390           238.735014
#
#            Prior_purchases  Discount_offered  Weight_in_gms
# Cluster A         5.654461          1.000000    1184.901461
# Cluster B         5.283210          4.919981    1426.868946
# Cluster C         4.832296          3.430697    2506.881557
# Cambios porcentuales en cada variable por cluster:
#            Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# Cluster A             0.099816         0.129263             0.013903
# Cluster B             0.017004         0.034999             0.006827
# Cluster C             0.028744         0.015396             0.018370
#
#            Prior_purchases  Discount_offered  Weight_in_gms
# Cluster A         0.073022          0.012464       0.142538
# Cluster B         0.004027          0.022329       0.000831
# Cluster C         0.043269          0.282364       0.500825

# %% [markdown]
# # **Resumen y conclusiones**
# Antes de la integración, se caracterizaron los bloques originales de la empresa (A, B, C, D, F) utilizando tanto variables categóricas (Mode_of_Shipment, Product_importance, Gender) como numéricas (Customer_care_calls, Customer_rating, Cost_of_the_Product, Prior_purchases, Discount_offered, Weight_in_gms). Se calcularon proporciones para las variables categóricas y medidas estadísticas como media, desviación estándar, asimetría y curtosis para las variables numéricas, con el objetivo de entender la distribución y la heterogeneidad dentro de cada bloque. Posteriormente, se aplicó un proceso de clusterización mediante K-Medoids considerando únicamente las variables numéricas, generando tres clusters de referencia que actuarían como los nuevos bloques A, B y C.
#
# Los clusters resultantes mostraron diferencias importantes en las características de los productos y clientes. Por ejemplo, el Cluster A se caracterizó por un mayor promedio de Customer_care_calls y Cost_of_the_Product, mientras que el Cluster B concentró productos con menor costo y mayores proporciones de retrasos en la entrega. Tras la integración de los datos de los bloques originales C, D, E y F hacia los clusters de referencia, se observaron cambios en los medoides: en particular, el Cluster C presentó un incremento significativo en Weight_in_gms y Discount_offered, reflejando la incorporación de productos más pesados y con mayores descuentos desde los bloques integrados. Los cambios porcentuales confirmaron que los bloques A y B se mantuvieron relativamente estables, mientras que el Cluster C experimentó ajustes más notables, especialmente en el peso de los productos y el descuento aplicado.
#
# El proceso permitió reducir de seis a tres bloques de manera eficiente, manteniendo la representatividad de los datos y preservando las características principales de cada grupo. La integración mediante K-Medoids facilitó identificar los productos más representativos de cada bloque y reasignar los datos de los bloques originales menos estratégicos (C, D, E, F) a los clusters de referencia. Esto proporciona a la empresa un marco consolidado para la reorganización logística, optimización de inventarios y análisis de desempeño de los productos por bloque, asegurando que las decisiones operativas se basen en datos consistentes y representativos.
